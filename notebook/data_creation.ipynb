# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests
from requests.exceptions import SSLError

# customisations - ensure tables show all columns
pd.set_option("display.max_columns", 100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def get_request(url,parameters=None, steamspy=False):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recursively try again
        return get_request(url, parameters, steamspy)
    
    if response:
        try:
            return response.json()
        except:
            False
    else:
        # We do not know how many pages steamspy has... and it seems to work well, so we will use no response to stop.
        if steamspy:
            return "stop"
        else :
            # response is none usually means too many requests. Wait and try again 
            print('No response, waiting 10 seconds...')
            time.sleep(10)
            print('Retrying.')
            return get_request(url, parameters, steamspy)

# %% [markdown]
# Define Download Data

# %%
def get_app_data(app_list, start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, appid in app_list[start:stop].items():
        print('Current index: {}'.format(index), end='\r')

        # retrive app data for a row, handled by supplied parser, and append to list
        try:
            data = parser(appid)
            app_data.append(data)
        except:
            print("Error with "+str(appid))
        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(app_list, start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    f= open(rel_path, 'w')
    f.write("0")
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
            #This just reads the initial line
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# Download Steam Data

# %%
def getAppListBatch(url, parameters):
    json_data = get_request(url, parameters=parameters)
    steam_id = pd.DataFrame.from_dict(json_data["response"]["apps"])
    try:
        more_results = json_data["response"]["have_more_results"]
        last_appid =  json_data["response"]["last_appid"]
    except:
        more_results = False
        last_appid = False
    return more_results, steam_id, last_appid

def get_update_ids_old(updatedlist, oldlist):
    updatedlist['key1'] = 1
    oldlist['key2'] = 1
    updatedlist = pd.merge(updatedlist, oldlist, right_on=['steam_appid','name'],left_on=['appid','name'], how = 'outer')
    updatedlist = updatedlist[~(updatedlist.key2 == updatedlist.key1)]
    updatedlist = updatedlist.drop(['key1','key2','steam_appid'], axis=1)
    return updatedlist

def get_update_ids(idList, oldFullList):
    #We are going to forget about names and only care about IDs.
    idList = idList["appid"]
    oldFullList = oldFullList["steam_appid"]
    oldFullList.columns = ["appid"]
    updatedList = pd.concat([idList, oldFullList])
    updatedList = updatedList.drop_duplicates(keep=False)
    updatedList = updatedList.reset_index(drop=True)
    return updatedList

# %%
def getAppList():
    with open('../data/steam_key.txt') as f:
        key = f.read()

    url = "https://api.steampowered.com/IStoreService/GetAppList/v1/?"
    parameters = {"key": key}
    more_results = True
    begin = True
    # from the request we get the more_results flag and also the last_appid, so we use them for the next requests.
    while (more_results):
        more_results, steam_ids, last_appid = getAppListBatch(url, parameters)
        parameters["last_appid"] = last_appid
        if (begin):
            steam_allids = steam_ids
            begin = False
        else:
            steam_allids = pd.concat([steam_allids, steam_ids])
    return steam_allids
# request 'all' from steam spy and parse into dataframe

# %%
def parse_steam_request(appid):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    with open('../data/steam_key.txt') as f:
        key = f.read()
        
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid, "key": key}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'steam_appid': appid}
        
    return data


# Set file parameters
download_path = '../data/download/'
steam_app_data = 'steam_app_data.csv'
steam_app_data_delta = 'steam_app_data_delta.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
if (os.path.isfile(download_path+steam_app_data_delta) == False):
    reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if no previous  data
if (os.path.isfile(download_path+steam_app_data) == False):
    prepare_data_file(download_path, steam_app_data, index, steam_columns)
    
# Wipe or create data file delta and write headers if index is 0
if (os.path.isfile(download_path+steam_app_data_delta) == False):
    prepare_data_file(download_path, steam_app_data_delta, index, steam_columns)
    
    
# Here we get the list of appids from steam
full_steam_ids = getAppList()

# Here we get the real list of ids not yet in our dataframe. If this is the first time we are downloading the data, we can skip
# This step and instead use the full app_list.
try:
    oldlist = pd.read_csv('../data/download/steam_app_data.csv', usecols = ['name','steam_appid'])
    steam_ids = get_update_ids(full_steam_ids, oldlist)
except FileNotFoundError:
    print("Pre-existing file not found. First time downloading full app data from steam. This will take a while.\n")
    steam_ids = full_steam_ids

# %%
print("New IDs detected: "+str(len(steam_ids)))
# Out:
# New IDs detected: 98460

# %%
# I separated the long process to be able to debug it better.
# Set end and chunksize for demonstration - remove to run through entire app list
# Here by default we passed "app_list" that contained all the information and saved it, now we will modify it a bit
# And add pre-processing and post-processing
print("Adding "+str(len(steam_ids))+" new ids.\n")
process_batches(
    parser=parse_steam_request,
    app_list=steam_ids,
    download_path=download_path,
    data_filename=steam_app_data_delta,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    #end=10,
    #batchsize=5
)

try:
    oldlist = pd.read_csv('../data/download/steam_app_data.csv')
    # We change the old file to backup, so remove any backup named this way before...
    os.rename('../data/download/steam_app_data.csv', '../data/download/steam_app_data_backup.csv')
    newlist = pd.read_csv('../data/download/steam_app_data_delta.csv')
    oldlist = oldlist.append(newlist, ignore_index=True)
    oldlist.to_csv('../data/download/steam_app_data.csv', index=False)
except FileNotFoundError:
    os.rename('../data/download/steam_app_data_delta.csv', '../data/download/steam_app_data.csv')
# Out:
# Adding 98460 new ids.
#
# Starting at index 0:
#
# Exported lines 0-99 to steam_app_data_delta.csv. Batch 0 time: 0:02:35 (avg: 0:02:35, remaining: 1 day, 18:26:54)
# Exported lines 100-199 to steam_app_data_delta.csv. Batch 1 time: 0:02:35 (avg: 0:02:35, remaining: 1 day, 18:24:03)
# Exported lines 97000-97099 to steam_app_data_delta.csv. Batch 970 time: 0:02:35 (avg: 0:02:39, remaining: 0:37:03)
# Exported lines 97100-97199 to steam_app_data_delta.csv. Batch 971 time: 0:02:36 (avg: 0:02:39, remaining: 0:34:25)
# Exported lines 97200-97299 to steam_app_data_delta.csv. Batch 972 time: 0:02:35 (avg: 0:02:39, remaining: 0:31:46)
# Exported lines 97300-97399 to steam_app_data_delta.csv. Batch 973 time: 0:02:35 (avg: 0:02:39, remaining: 0:29:07)
# Exported lines 97400-97499 to steam_app_data_delta.csv. Batch 974 time: 0:02:36 (avg: 0:02:39, remaining: 0:26:28)
# Exported lines 97500-97599 to steam_app_data_delta.csv. Batch 975 time: 0:02:35 (avg: 0:02:39, remaining: 0:23:49)
# Exported lines 97600-97699 to steam_app_data_delta.csv. Batch 976 time: 0:02:35 (avg: 0:02:39, remaining: 0:21:10)
# Exported lines 97700-97799 to steam_app_data_delta.csv. Batch 977 time: 0:02:37 (avg: 0:02:39, remaining: 0:18:32)
# Exported lines 97800-97899 to steam_app_data_delta.csv. Batch 978 time: 0:02:35 (avg: 0:02:39, remaining: 0:15:53)
# Exported lines 97900-97999 to steam_app_data_delta.csv. Batch 979 time: 0:02:36 (avg: 0:02:39, remaining: 0:13:14)
# Exported lines 98000-98099 to steam_app_data_delta.csv. Batch 980 time: 0:02:36 (avg: 0:02:39, remaining: 0:10:35)
# Exported lines 98100-98199 to steam_app_data_delta.csv. Batch 981 time: 0:02:36 (avg: 0:02:39, remaining: 0:07:56)
# Exported lines 98200-98299 to steam_app_data_delta.csv. Batch 982 time: 0:02:36 (avg: 0:02:39, remaining: 0:05:18)
# Exported lines 98300-98399 to steam_app_data_delta.csv. Batch 983 time: 0:02:36 (avg: 0:02:39, remaining: 0:02:39)
# Exported lines 98400-98460 to steam_app_data_delta.csv. Batch 984 time: 0:01:33 (avg: 0:02:39, remaining: 0:00:00)
#
# Processing batches complete. 98340 apps written
# C:\Users\jdejr\AppData\Local\Temp\ipykernel_58132\127405560.py:22: DtypeWarning: Columns (3,4,6,18,19,23,24,27,28,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   newlist = pd.read_csv('../data/download/steam_app_data_delta.csv')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_58132\127405560.py in ?()
#      21     os.rename('../data/download/steam_app_data.csv', '../data/download/steam_app_data_backup.csv')
#      22     newlist = pd.read_csv('../data/download/steam_app_data_delta.csv')
#      23     oldlist = oldlist.append(newlist, ignore_index=True)
#      24     oldlist.to_csv('../data/download/steam_app_data.csv', index=False)
# ---> 25 except FileNotFoundError:
#      26     os.rename('../data/download/steam_app_data_delta.csv', '../data/download/steam_app_data.csv')
#
# c:\Users\jdejr\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
os.rename('../data/download/steam_app_data_delta.csv', '../data/download/steam_app_data.csv')

# %%
steam_app_data = pd.read_csv('../data/download/steam_app_data.csv')
# Out:
# C:\Users\jdejr\AppData\Local\Temp\ipykernel_58132\3041477814.py:1: DtypeWarning: Columns (3,4,6,18,19,23,24,27,28,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   steam_app_data = pd.read_csv('../data/download/steam_app_data.csv')

# %%
steam_app_data
# Out:
#        type                             name  steam_appid required_age  \
# 0      game                   Counter-Strike           10          0.0
# 1      game            Team Fortress Classic           20          0.0
# 2      game                    Day of Defeat           30          0.0
# 3      game               Deathmatch Classic           40          0.0
# 4      game        Half-Life: Opposing Force           50          0.0
# ...     ...                              ...          ...          ...
# 98335  game                         TileTurn      2827910            0
# 98336  game                       CRASH MATH      2828060            0
# 98337  game                      Honor Bound      2828270            0
# 98338  game                           SAMARA      2829370            0
# 98339  game  Save Giant Girl from monsters 2      2830670            0
#
#       is_free controller_support  dlc  \
# 0       False                NaN  NaN
# 1       False                NaN  NaN
# 2       False                NaN  NaN
# 3       False                NaN  NaN
# 4       False                NaN  NaN
# ...       ...                ...  ...
# 98335   False                NaN  NaN
# 98336   False                NaN  NaN
# 98337   False                NaN  NaN
# 98338   False                NaN  NaN
# 98339   False                NaN  NaN
#
#                                     detailed_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 98335  <h2 class="bb_tag">Puzzles are waiting for you...
# 98336  CRASH MATH<br />\r\n<br />\r\nYou must solve m...
# 98337  Protect an exclusive boarding school and rebui...
# 98338  <strong>SAMARA</strong> is a first person, sin...
# 98339  A flight simulator game.<br />\r\nSave the gia...
#
#                                           about_the_game  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 98335  <h2 class="bb_tag">Puzzles are waiting for you...
# 98336  CRASH MATH<br />\r\n<br />\r\nYou must solve m...
# 98337  Protect an exclusive boarding school and rebui...
# 98338  <strong>SAMARA</strong> is a first person, sin...
# 98339  A flight simulator game.<br />\r\nSave the gia...
#
#                                        short_description  fullgame  \
# 0      Play the world's number 1 online action game. ...       NaN
# 1      One of the most popular online action games of...       NaN
# 2      Enlist in an intense brand of Axis vs. Allied ...       NaN
# 3      Enjoy fast-paced multiplayer gaming with Death...       NaN
# 4      Return to the Black Mesa Research Facility as ...       NaN
# ...                                                  ...       ...
# 98335  TiltTurn is a game where you need to solve swa...       NaN
# 98336  CRASH MATH - You must solve math problems whil...       NaN
# 98337  Protect an exclusive boarding school and rebui...       NaN
# 98338  SAMARA plunges player into a first person, sin...       NaN
# 98339  A flight simulator game. Save the giant girl f...       NaN
#
#                                      supported_languages  \
# 0      English<strong>*</strong>, French<strong>*</st...
# 1      English, French, German, Italian, Spanish - Sp...
# 2      English, French, German, Italian, Spanish - Spain
# 3      English, French, German, Italian, Spanish - Sp...
# 4                        English, French, German, Korean
# ...                                                  ...
# 98335  English, French, Italian, German, Spanish - Sp...
# 98336                                            English
# 98337                                            English
# 98338  English<strong>*</strong><br><strong>*</strong...
# 98339                                            English
#
#                                             header_image  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 98335  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98336  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98337  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98338  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98339  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                  website  \
# 0                                                    NaN
# 1                                                    NaN
# 2                            http://www.dayofdefeat.com/
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 98335                                                NaN
# 98336  http://store.steampowered.com/search/?publishe...
# 98337                                                NaN
# 98338                                                NaN
# 98339                                                NaN
#
#                                          pc_requirements  \
# 0      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4      {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# ...                                                  ...
# 98335  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 98336  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 98337  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 98338  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 98339  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                         mac_requirements  \
# 0      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 1      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 2      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 3      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# 4      {'minimum': 'Minimum: OS X  Snow Leopard 10.6....
# ...                                                  ...
# 98335                                                 []
# 98336                                                 []
# 98337  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 98338                                                 []
# 98339                                                 []
#
#                                       linux_requirements legal_notice  \
# 0      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN
# 1      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN
# 2      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN
# 3      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN
# 4      {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual...          NaN
# ...                                                  ...          ...
# 98335                                                 []          NaN
# 98336                                                 []          NaN
# 98337  {'minimum': '<strong>Minimum:</strong><br><ul ...          NaN
# 98338                                                 []          NaN
# 98339                                                 []          NaN
#
#       drm_notice ext_user_account_notice                          developers  \
# 0            NaN                     NaN                           ['Valve']
# 1            NaN                     NaN                           ['Valve']
# 2            NaN                     NaN                           ['Valve']
# 3            NaN                     NaN                           ['Valve']
# 4            NaN                     NaN                ['Gearbox Software']
# ...          ...                     ...                                 ...
# 98335        NaN                     NaN                    ['Petal Sakura']
# 98336        NaN                     NaN  ['Archor Wright', 'HOGuru Games!']
# 98337        NaN                     NaN                 ['Choice of Games']
# 98338        NaN                     NaN                     ['Shalini Deb']
# 98339        NaN                     NaN                            ['Hede']
#
#                               publishers demos  \
# 0                              ['Valve']   NaN
# 1                              ['Valve']   NaN
# 2                              ['Valve']   NaN
# 3                              ['Valve']   NaN
# 4                              ['Valve']   NaN
# ...                                  ...   ...
# 98335                   ['Petal Sakura']   NaN
# 98336  ['Archor Games', 'HOGuru Games!']   NaN
# 98337                ['Choice of Games']   NaN
# 98338                    ['Shalini Deb']   NaN
# 98339                           ['Hede']   NaN
#
#                                           price_overview      packages  \
# 0      {'currency': 'USD', 'initial': 999, 'final': 9...   [574941, 7]
# 1      {'currency': 'USD', 'initial': 499, 'final': 4...          [29]
# 2      {'currency': 'USD', 'initial': 499, 'final': 4...  [30, 944613]
# 3      {'currency': 'USD', 'initial': 499, 'final': 4...          [31]
# 4      {'currency': 'USD', 'initial': 499, 'final': 4...          [32]
# ...                                                  ...           ...
# 98335                                                NaN           NaN
# 98336                                                NaN           NaN
# 98337                                                NaN           NaN
# 98338                                                NaN           NaN
# 98339                                                NaN           NaN
#
#                                           package_groups  \
# 0      [{'name': 'default', 'title': 'Buy Counter-Str...
# 1      [{'name': 'default', 'title': 'Buy Team Fortre...
# 2      [{'name': 'default', 'title': 'Buy Day of Defe...
# 3      [{'name': 'default', 'title': 'Buy Deathmatch ...
# 4      [{'name': 'default', 'title': 'Buy Half-Life: ...
# ...                                                  ...
# 98335                                                 []
# 98336                                                 []
# 98337                                                 []
# 98338                                                 []
# 98339                                                 []
#
#                                              platforms  \
# 0        {'windows': True, 'mac': True, 'linux': True}
# 1        {'windows': True, 'mac': True, 'linux': True}
# 2        {'windows': True, 'mac': True, 'linux': True}
# 3        {'windows': True, 'mac': True, 'linux': True}
# 4        {'windows': True, 'mac': True, 'linux': True}
# ...                                                ...
# 98335  {'windows': True, 'mac': False, 'linux': False}
# 98336  {'windows': True, 'mac': False, 'linux': False}
# 98337    {'windows': True, 'mac': True, 'linux': True}
# 98338  {'windows': True, 'mac': False, 'linux': False}
# 98339  {'windows': True, 'mac': False, 'linux': False}
#
#                                               metacritic reviews  \
# 0      {'score': 88, 'url': 'https://www.metacritic.c...     NaN
# 1                                                    NaN     NaN
# 2      {'score': 79, 'url': 'https://www.metacritic.c...     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 98335                                                NaN     NaN
# 98336                                                NaN     NaN
# 98337                                                NaN     NaN
# 98338                                                NaN     NaN
# 98339                                                NaN     NaN
#
#                                               categories  \
# 0      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 3      [{'id': 1, 'description': 'Multi-player'}, {'i...
# 4      [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 98335  [{'id': 2, 'description': 'Single-player'}, {'...
# 98336        [{'id': 2, 'description': 'Single-player'}]
# 98337  [{'id': 2, 'description': 'Single-player'}, {'...
# 98338        [{'id': 2, 'description': 'Single-player'}]
# 98339  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 0                 [{'id': '1', 'description': 'Action'}]
# 1                 [{'id': '1', 'description': 'Action'}]
# 2                 [{'id': '1', 'description': 'Action'}]
# 3                 [{'id': '1', 'description': 'Action'}]
# 4                 [{'id': '1', 'description': 'Action'}]
# ...                                                  ...
# 98335  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 98336             [{'id': '9', 'description': 'Racing'}]
# 98337  [{'id': '25', 'description': 'Adventure'}, {'i...
# 98338  [{'id': '25', 'description': 'Adventure'}, {'i...
# 98339  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                              screenshots  \
# 0      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4      [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                  ...
# 98335  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 98336  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 98337  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 98338  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 98339  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies    recommendations  \
# 0                                                    NaN  {'total': 146647}
# 1                                                    NaN    {'total': 5888}
# 2                                                    NaN    {'total': 3937}
# 3                                                    NaN    {'total': 2062}
# 4                                                    NaN   {'total': 18014}
# ...                                                  ...                ...
# 98335  [{'id': 256999443, 'name': 'Gameplay', 'thumbn...                NaN
# 98336  [{'id': 256999415, 'name': 'CRASH MATH - Trail...                NaN
# 98337  [{'id': 256999466, 'name': 'Honor Bound traile...                NaN
# 98338                                                NaN                NaN
# 98339                                                NaN                NaN
#
#       achievements                                   release_date  \
# 0              NaN  {'coming_soon': False, 'date': 'Nov 1, 2000'}
# 1              NaN  {'coming_soon': False, 'date': 'Apr 1, 1999'}
# 2              NaN  {'coming_soon': False, 'date': 'May 1, 2003'}
# 3              NaN  {'coming_soon': False, 'date': 'Jun 1, 2001'}
# 4              NaN  {'coming_soon': False, 'date': 'Nov 1, 1999'}
# ...            ...                                            ...
# 98335          NaN  {'coming_soon': True, 'date': 'Mar 25, 2024'}
# 98336          NaN  {'coming_soon': True, 'date': 'Feb 20, 2024'}
# 98337          NaN   {'coming_soon': True, 'date': 'Coming soon'}
# 98338          NaN   {'coming_soon': True, 'date': 'Coming soon'}
# 98339          NaN  {'coming_soon': True, 'date': 'Feb 21, 2024'}
#
#                                             support_info  \
# 0      {'url': 'http://steamcommunity.com/app/10', 'e...
# 1                               {'url': '', 'email': ''}
# 2                               {'url': '', 'email': ''}
# 3                               {'url': '', 'email': ''}
# 4      {'url': 'https://help.steampowered.com', 'emai...
# ...                                                  ...
# 98335  {'url': '', 'email': 'petalsakuraofficial@gmai...
# 98336  {'url': 'http://store.steampowered.com/search/...
# 98337  {'url': 'https://www.choiceofgames.com/contact...
# 98338          {'url': '', 'email': 'aissbea@gmail.com'}
# 98339  {'url': 'http://hede.ru/', 'email': 'info@hede...
#
#                                               background  \
# 0      https://cdn.akamai.steamstatic.com/steam/apps/...
# 1      https://cdn.akamai.steamstatic.com/steam/apps/...
# 2      https://cdn.akamai.steamstatic.com/steam/apps/...
# 3      https://cdn.akamai.steamstatic.com/steam/apps/...
# 4      https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 98335  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98336  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98337  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98338  https://cdn.akamai.steamstatic.com/steam/apps/...
# 98339  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      content_descriptors
# 0      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 1      {'ids': [2, 5], 'notes': 'Includes intense vio...
# 2                             {'ids': [], 'notes': None}
# 3                             {'ids': [], 'notes': None}
# 4                             {'ids': [], 'notes': None}
# ...                                                  ...
# 98335                         {'ids': [], 'notes': None}
# 98336                         {'ids': [], 'notes': None}
# 98337                         {'ids': [], 'notes': None}
# 98338  {'ids': [5], 'notes': 'Samara is a psychologic...
# 98339                         {'ids': [], 'notes': None}
#
# [98340 rows x 39 columns]

# %%
steam_app_data[steam_app_data.duplicated(subset="steam_appid")]
# Out:
#        type                                               name  steam_appid  \
# 655    game  Tom Clancy's Splinter Cell Conviction™ Deluxe ...        33220
# 25052  game  The Elder Scrolls IV: Oblivion® Game of the Ye...        22330
# 25055  game                                      Earthworm Jim        38480
# 25056  game                  Sam & Max: The Devil’s Playhouse         31220
# 25058  game              Grand Theft Auto IV: Complete Edition        12210
# 25062  game                          The Stronghold Collection        40960
# 25063  game                   Fate of the World: Tipping Point        80200
#
#       required_age is_free controller_support      dlc  \
# 655           17.0   False                NaN  [33372]
# 25052         17.0   False                NaN      NaN
# 25055          0.0   False                NaN      NaN
# 25056          0.0   False                NaN      NaN
# 25058         17.0   False                NaN      NaN
# 25062          0.0   False                NaN      NaN
# 25063          0.0   False                NaN      NaN
#
#                                     detailed_description  \
# 655    An investigation into his daughter’s death unw...
# 25052  The Elder Scrolls IV: Oblivion® Game of the Ye...
# 25055  Jim wasn't always a studly super-worm. He was ...
# 25056  <p>5 Games, 1 Price! Delivered monthly</p>\n\t...
# 25058  <strong>PLEASE NOTE:  Microsoft no longer supp...
# 25062  Enjoy the complete medieval experience in The ...
# 25063  <p>Revised, rebalanced and expanded, Tipping P...
#
#                                           about_the_game  \
# 655    An investigation into his daughter’s death unw...
# 25052  The Elder Scrolls IV: Oblivion® Game of the Ye...
# 25055  Jim wasn't always a studly super-worm. He was ...
# 25056  <p>5 Games, 1 Price! Delivered monthly</p>\n\t...
# 25058  <strong>PLEASE NOTE:  Microsoft no longer supp...
# 25062  Enjoy the complete medieval experience in The ...
# 25063  <p>Revised, rebalanced and expanded, Tipping P...
#
#                                        short_description  fullgame  \
# 655    An investigation into his daughter’s death unw...       NaN
# 25052  The Elder Scrolls IV: Oblivion® Game of the Ye...       NaN
# 25055  Jim wasn't always a studly super-worm. He was ...       NaN
# 25056  5 Games, 1 Price! Delivered monthly Wield psyc...       NaN
# 25058  PLEASE NOTE: Microsoft no longer supports crea...       NaN
# 25062  Enjoy the complete medieval experience in The ...       NaN
# 25063  Experience Fate of the World as it's meant to ...       NaN
#
#                                      supported_languages  \
# 655    English, French, German, Italian, Spanish - Spain
# 25052                                            English
# 25055                                            English
# 25056                                            English
# 25058  English, French, German, Italian, Spanish - Spain
# 25062          English, German, Italian, Spanish - Spain
# 25063                             English, Dutch, German
#
#                                             header_image  \
# 655    https://cdn.akamai.steamstatic.com/steam/apps/...
# 25052  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25055  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25056  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25058  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25062  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25063  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                                 website  \
# 655          http://splintercell.us.ubi.com/conviction/
# 25052                       http://www.elderscrolls.com
# 25055                                               NaN
# 25056  http://www.samandmaxgames.com/thedevilsplayhouse
# 25058                   http://www.rockstargames.com/iv
# 25062                                               NaN
# 25063                     http://www.fateoftheworld.net
#
#                                          pc_requirements  \
# 655    {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 25052  {'minimum': '<ul class="bb_ul"><li><strong>OS ...
# 25055  {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 25056  {'minimum': '<ul>\n\t\t\t\t\t\t\t\t\t<li><stro...
# 25058  {'minimum': '<ul class="bb_ul"><li><strong>OS ...
# 25062  {'minimum': '<ul class="bb_ul"><li><strong>OS ...
# 25063  {'minimum': '<p><strong>Minimum:</strong></p>\...
#
#                                         mac_requirements linux_requirements  \
# 655    {'minimum': '<ul class="bb_ul">Does not suppor...                 []
# 25052                                                 []                 []
# 25055                                                 []                 []
# 25056  {'minimum': '<ul>\n\t\t\t\t\t\t\t\t\t<li><stro...                 []
# 25058                                                 []                 []
# 25062                                                 []                 []
# 25063  {'minimum': '<ul>\n\t\t\t\t\t<li><strong>OS:</...                 []
#
#                                             legal_notice drm_notice  \
# 655    HIGH SPEED INTERNET ACCESS AND CREATION OF A U...        NaN
# 25052  The Elder Scrolls IV: Oblivion® Game of the Ye...        NaN
# 25055                                                NaN        NaN
# 25056  © 2010 Telltale, Inc. Sam & Max created by Ste...        NaN
# 25058  Other Requirements: Initial activation require...   SecuROM™
# 25062  ©2009 Firefly Studios, Ltd. Stronghold, Strong...        NaN
# 25063  FATE OF THE WORLD © 2010, 2011 Red Redemption ...        NaN
#
#                                  ext_user_account_notice  \
# 655    Ubisoft account required (Supports Linking to ...
# 25052                                                NaN
# 25055                                                NaN
# 25056                                                NaN
# 25058                                                NaN
# 25062                                                NaN
# 25063                                                NaN
#
#                                    developers              publishers demos  \
# 655                      ['Ubisoft Montreal']             ['Ubisoft']   NaN
# 25052              ['Bethesda Game Studios®']  ['Bethesda Softworks']   NaN
# 25055                 ['Shiny Entertainment']      ['Interplay Inc.']   NaN
# 25056                      ['Telltale Games']      ['Telltale Games']   NaN
# 25058  ['Rockstar North', 'Rockstar Toronto']      ['Rockstar Games']   NaN
# 25062                     ['FireFly Studios']     ['FireFly Studios']   NaN
# 25063                      ['Red Redemption']      ['Red Redemption']   NaN
#
#                                           price_overview      packages  \
# 655    {'currency': 'USD', 'initial': 1999, 'final': ...  [4261, 4158]
# 25052  {'currency': 'USD', 'initial': 1999, 'final': ...  [1679, 1678]
# 25055  {'currency': 'USD', 'initial': 1999, 'final': ...        [2382]
# 25056  {'currency': 'USD', 'initial': 999, 'final': 9...        [4172]
# 25058                                                NaN           NaN
# 25062  {'currency': 'USD', 'initial': 2499, 'final': ...        [4375]
# 25063  {'currency': 'USD', 'initial': 1899, 'final': ...       [11769]
#
#                                           package_groups  \
# 655    [{'name': 'default', 'title': "Buy Tom Clancy'...
# 25052  [{'name': 'default', 'title': 'Buy The Elder S...
# 25055  [{'name': 'default', 'title': 'Buy Earthworm J...
# 25056  [{'name': 'default', 'title': 'Buy Sam & Max: ...
# 25058                                                 []
# 25062  [{'name': 'default', 'title': 'Buy The Strongh...
# 25063  [{'name': 'default', 'title': 'Buy Fate of the...
#
#                                              platforms  \
# 655    {'windows': True, 'mac': False, 'linux': False}
# 25052  {'windows': True, 'mac': False, 'linux': False}
# 25055    {'windows': True, 'mac': True, 'linux': True}
# 25056   {'windows': True, 'mac': True, 'linux': False}
# 25058  {'windows': True, 'mac': False, 'linux': False}
# 25062  {'windows': True, 'mac': False, 'linux': False}
# 25063   {'windows': True, 'mac': True, 'linux': False}
#
#                                               metacritic reviews  \
# 655    {'score': 83, 'url': 'https://www.metacritic.c...     NaN
# 25052  {'score': 94, 'url': 'https://www.metacritic.c...     NaN
# 25055                                                NaN     NaN
# 25056                                                NaN     NaN
# 25058  {'score': 90, 'url': 'https://www.metacritic.c...     NaN
# 25062                                                NaN     NaN
# 25063  {'score': 70, 'url': 'https://www.metacritic.c...     NaN
#
#                                               categories  \
# 655    [{'id': 2, 'description': 'Single-player'}, {'...
# 25052  [{'id': 2, 'description': 'Single-player'}, {'...
# 25055        [{'id': 2, 'description': 'Single-player'}]
# 25056        [{'id': 2, 'description': 'Single-player'}]
# 25058  [{'id': 2, 'description': 'Single-player'}, {'...
# 25062  [{'id': 2, 'description': 'Single-player'}, {'...
# 25063  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 655               [{'id': '1', 'description': 'Action'}]
# 25052                                                NaN
# 25055  [{'id': '1', 'description': 'Action'}, {'id': ...
# 25056         [{'id': '25', 'description': 'Adventure'}]
# 25058  [{'id': '1', 'description': 'Action'}, {'id': ...
# 25062           [{'id': '2', 'description': 'Strategy'}]
# 25063  [{'id': '2', 'description': 'Strategy'}, {'id'...
#
#                                              screenshots  \
# 655    [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25052  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25055  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25056  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25058  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25062  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25063  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies    recommendations  \
# 655                                                  NaN    {'total': 3613}
# 25052  [{'id': 5286, 'name': 'The Elder Scrolls IV: O...   {'total': 35500}
# 25055                                                NaN     {'total': 131}
# 25056                                                NaN     {'total': 291}
# 25058                                                NaN  {'total': 126533}
# 25062                                                NaN    {'total': 3984}
# 25063                                                NaN     {'total': 377}
#
#                                             achievements  \
# 655                                                  NaN
# 25052                                                NaN
# 25055                                                NaN
# 25056                                                NaN
# 25058  {'total': 55, 'highlighted': [{'name': 'Off Th...
# 25062  {'total': 33, 'highlighted': [{'name': 'Becaus...
# 25063  {'total': 32, 'highlighted': [{'name': 'Step F...
#
#                                          release_date  \
# 655    {'coming_soon': False, 'date': 'Apr 29, 2010'}
# 25052  {'coming_soon': False, 'date': 'Jun 16, 2009'}
# 25055   {'coming_soon': False, 'date': 'Nov 4, 2009'}
# 25056  {'coming_soon': False, 'date': 'Apr 15, 2010'}
# 25058              {'coming_soon': False, 'date': ''}
# 25062  {'coming_soon': False, 'date': 'Oct 27, 2009'}
# 25063  {'coming_soon': False, 'date': 'Sep 29, 2011'}
#
#                                             support_info  \
# 655                             {'url': '', 'email': ''}
# 25052                           {'url': '', 'email': ''}
# 25055                           {'url': '', 'email': ''}
# 25056                           {'url': '', 'email': ''}
# 25058                           {'url': '', 'email': ''}
# 25062     {'url': 'http://support.2k.com/', 'email': ''}
# 25063  {'url': '', 'email': 'support@red-redemption.c...
#
#                                               background  \
# 655    https://cdn.akamai.steamstatic.com/steam/apps/...
# 25052  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25055  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25056  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25058  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25062  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25063  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#               content_descriptors
# 655    {'ids': [], 'notes': None}
# 25052  {'ids': [], 'notes': None}
# 25055  {'ids': [], 'notes': None}
# 25056  {'ids': [], 'notes': None}
# 25058  {'ids': [], 'notes': None}
# 25062  {'ids': [], 'notes': None}
# 25063  {'ids': [], 'notes': None}

# %%
steam_app_data[steam_app_data["steam_appid"] == 34330]
# Out:
#       type                 name  steam_appid required_age is_free  \
# 1297  game  Total War: SHOGUN 2        34330          0.0   False
#
#      controller_support                                                dlc  \
# 1297                NaN  [223180, 201279, 201277, 34348, 34342, 34343, ...
#
#                                    detailed_description  \
# 1297  <h1>Total War: SHOGUN 2 out now for Linux.</h1...
#
#                                          about_the_game  \
# 1297  <strong>MASTER THE ART OF WAR</strong><br>\t\t...
#
#                                       short_description  fullgame  \
# 1297  Total War: SHOGUN 2 is the perfect mix of real...       NaN
#
#                                     supported_languages  \
# 1297  English<strong>*</strong>, Czech, French<stron...
#
#                                            header_image  \
# 1297  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                               website  \
# 1297  http://www.totalwar.com/shogun2
#
#                                         pc_requirements  \
# 1297  {'minimum': '<strong>Minimum:</strong><br>\t\t...
#
#                                        mac_requirements  \
# 1297  {'minimum': '<ul class="bb_ul"><li><strong>OS:...
#
#                                      linux_requirements  \
# 1297  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                            legal_notice drm_notice  \
# 1297  © SEGA. SEGA and the SEGA logo are registered ...        NaN
#
#      ext_user_account_notice  \
# 1297                     NaN
#
#                                              developers  \
# 1297  ['CREATIVE ASSEMBLY', 'Feral Interactive (Mac)...
#
#                                              publishers  \
# 1297  ['SEGA', 'Feral Interactive (Mac)', 'Feral Int...
#
#                                       demos  \
# 1297  [{'appid': 34350, 'description': ''}]
#
#                                          price_overview       packages  \
# 1297  {'currency': 'USD', 'initial': 2999, 'final': ...  [7587, 18408]
#
#                                          package_groups  \
# 1297  [{'name': 'default', 'title': 'Buy Total War: ...
#
#                                           platforms  \
# 1297  {'windows': True, 'mac': True, 'linux': True}
#
#                                              metacritic  \
# 1297  {'score': 90, 'url': 'https://www.metacritic.c...
#
#                                                 reviews  \
# 1297  “...the best gameplay and design of any entry ...
#
#                                              categories  \
# 1297  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                         genres  \
# 1297  [{'id': '2', 'description': 'Strategy'}]
#
#                                             screenshots movies  \
# 1297  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...    NaN
#
#        recommendations                                       achievements  \
# 1297  {'total': 31187}  {'total': 106, 'highlighted': [{'name': 'Stran...
#
#                                         release_date  \
# 1297  {'coming_soon': False, 'date': 'Mar 15, 2011'}
#
#                                            support_info  \
# 1297  {'url': 'https://support.sega.co.uk', 'email':...
#
#                                              background  \
# 1297  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#              content_descriptors
# 1297  {'ids': [], 'notes': None}

# %%
len(steam_app_data)-len(full_steam_ids)
# Out:
# -120

# %%
diff_ids = get_update_ids(full_steam_ids, steam_app_data)

# %%
len(diff_ids)
# Out:
# 135
