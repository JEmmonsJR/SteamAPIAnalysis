# %% [markdown]
# This is the Steam Review portion of the Steam API. This downloaded review data for every game entry on Steam as of 2/6/2024 and exported it into a csv for further use.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests
from requests.exceptions import SSLError

# customisations - ensure tables show all columns
pd.set_option("display.max_columns", 100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def get_request(url,parameters=None, steamspy=False):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recursively try again
        return get_request(url, parameters, steamspy)
    
    if response:
        try:
            return response.json()
        except:
            False
    else:
        # We do not know how many pages steamspy has... and it seems to work well, so we will use no response to stop.
        if steamspy:
            return "stop"
        else :
            # response is none usually means too many requests. Wait and try again 
            print('No response, waiting 10 seconds...')
            time.sleep(10)
            print('Retrying.')
            return get_request(url, parameters, steamspy)

# %% [markdown]
# Define Download Data

# %%
def get_app_data(app_list, start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, appid in app_list[start:stop].items():
        print('Current index: {}'.format(index), end='\r')

        # retrive app data for a row, handled by supplied parser, and append to list
        try:
            data = parser(appid)
            app_data.append(data)
        except:
            print("Error with "+str(appid))
        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(app_list, start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    f= open(rel_path, 'w')
    f.write("0")
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
            #This just reads the initial line
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# Steam Reviews

# %%
def parse_steamreviews_request(appid):
    """Parser to handle SteamSpy API data."""
    url = "https://store.steampowered.com/appreviews/" + str(appid)
    parameters = {"json": 1, "num_per_page": "0", "language": "all", "purchase_type": "all"}
    json_data = get_request(url, parameters)
    json_data = json_data['query_summary']
    json_data["appid"]=appid
    return json_data


# set files and columns
download_path = '../data/download'
steamreviews_data = 'steamreviews_data.csv'
steamreviews_index = 'steamreviews_index.txt'

steamreviews_columns = [
    'appid', 'review_score', 'review_score_desc', 'total_positive', 'total_negative', 'total_reviews'
]

reset_index(download_path, steamreviews_index)
index = get_index(download_path, steamreviews_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamreviews_data, index, steamreviews_columns)

full_steam_ids=pd.read_csv("../data/download/steam_app_data.csv")

process_batches(
    parser=parse_steamreviews_request,
    app_list=full_steam_ids["steam_appid"],
    download_path=download_path, 
    data_filename=steamreviews_data,
    index_filename=steamreviews_index,
    columns=steamreviews_columns,
    begin=index,
    end=len(full_steam_ids),
    batchsize=300,
    pause=0
)
# Out:
# C:\Users\jdejr\AppData\Local\Temp\ipykernel_24216\642713319.py:26: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_steam_ids=pd.read_csv("../data/download/steam_app_data.csv")
# Starting at index 0:
#
# Exported lines 0-299 to steamreviews_data.csv. Batch 0 time: 0:02:11 (avg: 0:02:11, remaining: 11:51:56)
# Exported lines 300-599 to steamreviews_data.csv. Batch 1 time: 0:02:18 (avg: 0:02:14, remaining: 12:08:50)
# Exported lines 600-899 to steamreviews_data.csv. Batch 2 time: 0:02:10 (avg: 0:02:13, remaining: 11:58:41)
# Exported lines 900-1199 to steamreviews_data.csv. Batch 3 time: 0:02:10 (avg: 0:02:12, remaining: 11:52:37)
# Exported lines 73200-73499 to steamreviews_data.csv. Batch 244 time: 0:02:14 (avg: 0:02:10, remaining: 3:00:21)
# Exported lines 73500-73799 to steamreviews_data.csv. Batch 245 time: 0:02:16 (avg: 0:02:10, remaining: 2:58:12)
# Exported lines 73800-74099 to steamreviews_data.csv. Batch 246 time: 0:02:12 (avg: 0:02:10, remaining: 2:56:02)
# Exported lines 74100-74399 to steamreviews_data.csv. Batch 247 time: 0:02:12 (avg: 0:02:10, remaining: 2:53:52)
# Exported lines 74400-74699 to steamreviews_data.csv. Batch 248 time: 0:02:13 (avg: 0:02:10, remaining: 2:51:43)
# Exported lines 74700-74999 to steamreviews_data.csv. Batch 249 time: 0:02:14 (avg: 0:02:10, remaining: 2:49:33)
# Error with 216319023
# Exported lines 75000-75299 to steamreviews_data.csv. Batch 250 time: 0:02:38 (avg: 0:02:11, remaining: 2:47:31)
# Exported lines 75300-75599 to steamreviews_data.csv. Batch 251 time: 0:02:11 (avg: 0:02:11, remaining: 2:45:21)
# Exported lines 75600-75899 to steamreviews_data.csv. Batch 252 time: 0:02:11 (avg: 0:02:11, remaining: 2:43:11)
# Exported lines 75900-76199 to steamreviews_data.csv. Batch 253 time: 0:02:10 (avg: 0:02:11, remaining: 2:41:00)
# Exported lines 76200-76499 to steamreviews_data.csv. Batch 254 time: 0:02:15 (avg: 0:02:11, remaining: 2:38:51)
# Exported lines 76500-76799 to steamreviews_data.csv. Batch 255 time: 0:02:11 (avg: 0:02:11, remaining: 2:36:40)
# Exported lines 76800-77099 to steamreviews_data.csv. Batch 256 time: 0:02:13 (avg: 0:02:11, remaining: 2:34:30)
# Exported lines 77100-77399 to steamreviews_data.csv. Batch 257 time: 0:02:11 (avg: 0:02:11, remaining: 2:32:20)
# Exported lines 77400-77699 to steamreviews_data.csv. Batch 258 time: 0:02:13 (avg: 0:02:11, remaining: 2:30:10)
# Exported lines 77700-77999 to steamreviews_data.csv. Batch 259 time: 0:02:14 (avg: 0:02:11, remaining: 2:28:00)
# Exported lines 78000-78299 to steamreviews_data.csv. Batch 260 time: 0:02:11 (avg: 0:02:11, remaining: 2:25:50)
# Exported lines 78300-78599 to steamreviews_data.csv. Batch 261 time: 0:02:11 (avg: 0:02:11, remaining: 2:23:39)
# Exported lines 78600-78899 to steamreviews_data.csv. Batch 262 time: 0:02:15 (avg: 0:02:11, remaining: 2:21:30)
# Exported lines 78900-79199 to steamreviews_data.csv. Batch 263 time: 0:02:11 (avg: 0:02:11, remaining: 2:19:19)
# Error with 226977046
# Exported lines 79200-79499 to steamreviews_data.csv. Batch 264 time: 0:02:35 (avg: 0:02:11, remaining: 2:17:15)
# Exported lines 79500-79799 to steamreviews_data.csv. Batch 265 time: 0:02:14 (avg: 0:02:11, remaining: 2:15:05)
# Exported lines 79800-80099 to steamreviews_data.csv. Batch 266 time: 0:02:15 (avg: 0:02:11, remaining: 2:12:55)
# Error with 228959018
# Exported lines 80100-80399 to steamreviews_data.csv. Batch 267 time: 0:02:32 (avg: 0:02:11, remaining: 2:10:49)
# Exported lines 80400-80699 to steamreviews_data.csv. Batch 268 time: 0:02:11 (avg: 0:02:11, remaining: 2:08:38)
# Exported lines 80700-80999 to steamreviews_data.csv. Batch 269 time: 0:02:10 (avg: 0:02:11, remaining: 2:06:27)
# Exported lines 81000-81299 to steamreviews_data.csv. Batch 270 time: 0:02:11 (avg: 0:02:11, remaining: 2:04:16)
# Exported lines 81300-81599 to steamreviews_data.csv. Batch 271 time: 0:02:09 (avg: 0:02:11, remaining: 2:02:05)
# Exported lines 81600-81899 to steamreviews_data.csv. Batch 272 time: 0:02:10 (avg: 0:02:11, remaining: 1:59:54)
# Exported lines 81900-82199 to steamreviews_data.csv. Batch 273 time: 0:02:10 (avg: 0:02:11, remaining: 1:57:43)
# Exported lines 82200-82499 to steamreviews_data.csv. Batch 274 time: 0:02:08 (avg: 0:02:11, remaining: 1:55:32)
# Exported lines 82500-82799 to steamreviews_data.csv. Batch 275 time: 0:02:12 (avg: 0:02:11, remaining: 1:53:21)
# Exported lines 82800-83099 to steamreviews_data.csv. Batch 276 time: 0:02:11 (avg: 0:02:11, remaining: 1:51:11)
# Exported lines 83100-83399 to steamreviews_data.csv. Batch 277 time: 0:02:10 (avg: 0:02:11, remaining: 1:49:00)
# Exported lines 83400-83699 to steamreviews_data.csv. Batch 278 time: 0:02:11 (avg: 0:02:11, remaining: 1:46:49)
# Exported lines 83700-83999 to steamreviews_data.csv. Batch 279 time: 0:02:11 (avg: 0:02:11, remaining: 1:44:38)
# Exported lines 84000-84299 to steamreviews_data.csv. Batch 280 time: 0:02:13 (avg: 0:02:11, remaining: 1:42:28)
# Exported lines 84300-84599 to steamreviews_data.csv. Batch 281 time: 0:02:12 (avg: 0:02:11, remaining: 1:40:17)
# Exported lines 84600-84899 to steamreviews_data.csv. Batch 282 time: 0:02:13 (avg: 0:02:11, remaining: 1:38:07)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 84900-85199 to steamreviews_data.csv. Batch 283 time: 0:03:21 (avg: 0:02:11, remaining: 1:36:07)
# Exported lines 85200-85499 to steamreviews_data.csv. Batch 284 time: 0:02:14 (avg: 0:02:11, remaining: 1:33:56)
# Exported lines 85500-85799 to steamreviews_data.csv. Batch 285 time: 0:02:14 (avg: 0:02:11, remaining: 1:31:46)
# Exported lines 85800-86099 to steamreviews_data.csv. Batch 286 time: 0:02:10 (avg: 0:02:11, remaining: 1:29:34)
# Exported lines 86100-86399 to steamreviews_data.csv. Batch 287 time: 0:02:12 (avg: 0:02:11, remaining: 1:27:23)
# Exported lines 86400-86699 to steamreviews_data.csv. Batch 288 time: 0:02:11 (avg: 0:02:11, remaining: 1:25:12)
# Exported lines 86700-86999 to steamreviews_data.csv. Batch 289 time: 0:02:09 (avg: 0:02:11, remaining: 1:23:01)
# Exported lines 87000-87299 to steamreviews_data.csv. Batch 290 time: 0:02:13 (avg: 0:02:11, remaining: 1:20:50)
# Exported lines 87300-87599 to steamreviews_data.csv. Batch 291 time: 0:02:10 (avg: 0:02:11, remaining: 1:18:39)
# Exported lines 87600-87899 to steamreviews_data.csv. Batch 292 time: 0:02:09 (avg: 0:02:11, remaining: 1:16:27)
# Exported lines 87900-88199 to steamreviews_data.csv. Batch 293 time: 0:02:13 (avg: 0:02:11, remaining: 1:14:17)
# Exported lines 88200-88499 to steamreviews_data.csv. Batch 294 time: 0:02:13 (avg: 0:02:11, remaining: 1:12:06)
# Exported lines 88500-88799 to steamreviews_data.csv. Batch 295 time: 0:02:11 (avg: 0:02:11, remaining: 1:09:55)
# Exported lines 88800-89099 to steamreviews_data.csv. Batch 296 time: 0:02:11 (avg: 0:02:11, remaining: 1:07:44)
# Exported lines 89100-89399 to steamreviews_data.csv. Batch 297 time: 0:02:11 (avg: 0:02:11, remaining: 1:05:32)
# Exported lines 89400-89699 to steamreviews_data.csv. Batch 298 time: 0:02:11 (avg: 0:02:11, remaining: 1:03:21)
# Exported lines 89700-89999 to steamreviews_data.csv. Batch 299 time: 0:02:12 (avg: 0:02:11, remaining: 1:01:10)
# Exported lines 90000-90299 to steamreviews_data.csv. Batch 300 time: 0:02:13 (avg: 0:02:11, remaining: 0:58:59)
# Error with 256025040
# Exported lines 90300-90599 to steamreviews_data.csv. Batch 301 time: 0:02:32 (avg: 0:02:11, remaining: 0:56:50)
# Exported lines 90600-90899 to steamreviews_data.csv. Batch 302 time: 0:02:11 (avg: 0:02:11, remaining: 0:54:39)
# Exported lines 90900-91199 to steamreviews_data.csv. Batch 303 time: 0:02:15 (avg: 0:02:11, remaining: 0:52:28)
# Exported lines 91200-91499 to steamreviews_data.csv. Batch 304 time: 0:02:12 (avg: 0:02:11, remaining: 0:50:17)
# Exported lines 91500-91799 to steamreviews_data.csv. Batch 305 time: 0:02:12 (avg: 0:02:11, remaining: 0:48:06)
# Exported lines 91800-92099 to steamreviews_data.csv. Batch 306 time: 0:02:14 (avg: 0:02:11, remaining: 0:45:55)
# Exported lines 92100-92399 to steamreviews_data.csv. Batch 307 time: 0:02:11 (avg: 0:02:11, remaining: 0:43:44)
# Exported lines 92400-92699 to steamreviews_data.csv. Batch 308 time: 0:02:17 (avg: 0:02:11, remaining: 0:41:33)
# Exported lines 92700-92999 to steamreviews_data.csv. Batch 309 time: 0:02:14 (avg: 0:02:11, remaining: 0:39:22)
# Exported lines 93000-93299 to steamreviews_data.csv. Batch 310 time: 0:02:13 (avg: 0:02:11, remaining: 0:37:11)
# Exported lines 93300-93599 to steamreviews_data.csv. Batch 311 time: 0:02:13 (avg: 0:02:11, remaining: 0:34:59)
# Exported lines 93600-93899 to steamreviews_data.csv. Batch 312 time: 0:02:13 (avg: 0:02:11, remaining: 0:32:48)
# Exported lines 93900-94199 to steamreviews_data.csv. Batch 313 time: 0:02:11 (avg: 0:02:11, remaining: 0:30:37)
# Exported lines 94200-94499 to steamreviews_data.csv. Batch 314 time: 0:02:12 (avg: 0:02:11, remaining: 0:28:26)
# Error with 268964055
# Exported lines 94500-94799 to steamreviews_data.csv. Batch 315 time: 0:02:35 (avg: 0:02:11, remaining: 0:26:16)
# Exported lines 94800-95099 to steamreviews_data.csv. Batch 316 time: 0:02:13 (avg: 0:02:11, remaining: 0:24:04)
# Exported lines 95100-95399 to steamreviews_data.csv. Batch 317 time: 0:02:16 (avg: 0:02:11, remaining: 0:21:53)
# Error with 271106084
# Exported lines 95400-95699 to steamreviews_data.csv. Batch 318 time: 0:02:36 (avg: 0:02:11, remaining: 0:19:43)
# Exported lines 95700-95999 to steamreviews_data.csv. Batch 319 time: 0:02:13 (avg: 0:02:11, remaining: 0:17:31)
# Exported lines 96000-96299 to steamreviews_data.csv. Batch 320 time: 0:02:10 (avg: 0:02:11, remaining: 0:15:20)
# Exported lines 96300-96599 to steamreviews_data.csv. Batch 321 time: 0:02:11 (avg: 0:02:11, remaining: 0:13:08)
# Exported lines 96600-96899 to steamreviews_data.csv. Batch 322 time: 0:02:12 (avg: 0:02:11, remaining: 0:10:57)
# Exported lines 96900-97199 to steamreviews_data.csv. Batch 323 time: 0:02:12 (avg: 0:02:11, remaining: 0:08:46)
# Exported lines 97200-97499 to steamreviews_data.csv. Batch 324 time: 0:02:14 (avg: 0:02:11, remaining: 0:06:34)
# Exported lines 97500-97799 to steamreviews_data.csv. Batch 325 time: 0:02:11 (avg: 0:02:11, remaining: 0:04:23)
# Exported lines 97800-98099 to steamreviews_data.csv. Batch 326 time: 0:02:15 (avg: 0:02:11, remaining: 0:02:11)
# Exported lines 98100-98169 to steamreviews_data.csv. Batch 327 time: 0:00:32 (avg: 0:02:11, remaining: 0:00:00)
#
# Processing batches complete. 98151 apps written

# %%
steamreviews=pd.read_csv("../data/download/steamreviews_data.csv", index_col="appid")

# %%
steamreviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98151 entries, 10 to 2830670
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   review_score       98151 non-null  int64
#  1   review_score_desc  98151 non-null  object
#  2   total_positive     98151 non-null  int64
#  3   total_negative     98151 non-null  int64
#  4   total_reviews      98151 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 4.5+ MB

# %%
steamreviews["total_reviews"].value_counts()
# Out:
# total_reviews
# 0         23763
# 1          3730
# 2          3112
# 3          2888
# 4          2563
#           ...
# 16253         1
# 650144        1
# 27230         1
# 23957         1
# 2469          1
# Name: count, Length: 5437, dtype: int64

# %%
steamreviews["review_score_desc"].value_counts()
# Out:
# review_score_desc
# No user reviews            23763
# Very Positive              14193
# Mixed                      13322
# Positive                   11592
# Mostly Positive             9500
# 1 user reviews              3730
# 2 user reviews              3112
# 3 user reviews              2888
# 4 user reviews              2563
# 5 user reviews              2371
# Mostly Negative             2174
# 6 user reviews              2138
# 7 user reviews              1894
# 8 user reviews              1738
# 9 user reviews              1636
# Overwhelmingly Positive     1160
# Negative                     311
# Very Negative                 53
# Overwhelmingly Negative       13
# Name: count, dtype: int64

# %%
steamreviews["review_score"].value_counts()
# Out:
# review_score
# 0    45833
# 8    14193
# 5    13322
# 7    11592
# 6     9500
# 4     2174
# 9     1160
# 3      311
# 2       53
# 1       13
# Name: count, dtype: int64
