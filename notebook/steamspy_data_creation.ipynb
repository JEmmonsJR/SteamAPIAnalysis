# %% [markdown]
# This uses the SteamSpy API. This downloaded player activity for every game entry on Steam as of 2/6/2024 and exported it into a csv for further use.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests
from requests.exceptions import SSLError

# customisations - ensure tables show all columns
pd.set_option("display.max_columns", 100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def get_request(url,parameters=None, steamspy=False):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recursively try again
        return get_request(url, parameters, steamspy)
    
    if response:
        try:
            return response.json()
        except:
            False
    else:
        # We do not know how many pages steamspy has... and it seems to work well, so we will use no response to stop.
        if steamspy:
            return "stop"
        else :
            # response is none usually means too many requests. Wait and try again 
            print('No response, waiting 10 seconds...')
            time.sleep(10)
            print('Retrying.')
            return get_request(url, parameters, steamspy)

# %% [markdown]
# Define Download Data

# %%
def get_app_data(app_list, start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, appid in app_list[start:stop].items():
        print('Current index: {}'.format(index), end='\r')

        # retrive app data for a row, handled by supplied parser, and append to list
        try:
            data = parser(appid)
            app_data.append(data)
        except:
            print("Error with "+str(appid))
        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(app_list, start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    f= open(rel_path, 'w')
    f.write("0")
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
            #This just reads the initial line
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# Steam Spy API

# %%
def parse_steamspy_request(appid):
    """Parser to handle SteamSpy API data."""
    url = "https://steamspy.com/api.php"
    parameters = {"request": "appdetails", "appid": appid}
    
    json_data = get_request(url, parameters)
    return json_data


# set files and columns
download_path = '../data/download'
steamspy_data = 'steamspy_data.csv'
steamspy_index = 'steamspy_index.txt'

steamspy_columns = [
    'appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
    'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
    'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
    'languages', 'genre', 'ccu', 'tags'
]

reset_index(download_path, steamspy_index)
index = get_index(download_path, steamspy_index)

# Wipe data file if index is 0
prepare_data_file(download_path, steamspy_data, index, steamspy_columns)

process_batches(
    parser=parse_steamspy_request,
    app_list=full_steam_ids["appid"],
    download_path=download_path, 
    data_filename=steamspy_data,
    index_filename=steamspy_index,
    columns=steamspy_columns,
    begin=index,
    end=len(full_steam_ids),
    batchsize=300,
    pause=0.1
)
# Out:
# Starting at index 0:
#
# Exported lines 0-299 to steamspy_data.csv. Batch 0 time: 0:02:40 (avg: 0:02:40, remaining: 14:39:09)
# Exported lines 300-599 to steamspy_data.csv. Batch 1 time: 0:02:19 (avg: 0:02:30, remaining: 13:37:37)
# Exported lines 600-899 to steamspy_data.csv. Batch 2 time: 0:02:27 (avg: 0:02:29, remaining: 13:31:15)
# Exported lines 900-1199 to steamspy_data.csv. Batch 3 time: 0:02:28 (avg: 0:02:29, remaining: 13:27:07)
# Exported lines 1200-1499 to steamspy_data.csv. Batch 4 time: 0:02:31 (avg: 0:02:29, remaining: 13:27:45)
# Exported lines 1500-1799 to steamspy_data.csv. Batch 5 time: 0:02:52 (avg: 0:02:33, remaining: 13:46:10)
# Exported lines 1800-2099 to steamspy_data.csv. Batch 6 time: 0:02:51 (avg: 0:02:36, remaining: 13:57:33)
# Exported lines 78600-78899 to steamspy_data.csv. Batch 262 time: 0:02:30 (avg: 0:02:37, remaining: 2:55:26)
# Exported lines 78900-79199 to steamspy_data.csv. Batch 263 time: 0:02:29 (avg: 0:02:37, remaining: 2:52:47)
# Exported lines 79200-79499 to steamspy_data.csv. Batch 264 time: 0:02:30 (avg: 0:02:37, remaining: 2:50:08)
# Exported lines 79500-79799 to steamspy_data.csv. Batch 265 time: 0:02:29 (avg: 0:02:37, remaining: 2:47:29)
# Exported lines 79800-80099 to steamspy_data.csv. Batch 266 time: 0:02:30 (avg: 0:02:37, remaining: 2:44:51)
# Exported lines 80100-80399 to steamspy_data.csv. Batch 267 time: 0:02:30 (avg: 0:02:37, remaining: 2:42:12)
# Exported lines 80400-80699 to steamspy_data.csv. Batch 268 time: 0:02:51 (avg: 0:02:37, remaining: 2:39:38)
# Exported lines 80700-80999 to steamspy_data.csv. Batch 269 time: 0:02:29 (avg: 0:02:37, remaining: 2:37:00)
# Exported lines 81000-81299 to steamspy_data.csv. Batch 270 time: 0:02:27 (avg: 0:02:37, remaining: 2:34:20)
# Exported lines 81300-81599 to steamspy_data.csv. Batch 271 time: 0:02:31 (avg: 0:02:37, remaining: 2:31:42)
# Exported lines 81600-81899 to steamspy_data.csv. Batch 272 time: 0:02:30 (avg: 0:02:37, remaining: 2:29:04)
# Exported lines 81900-82199 to steamspy_data.csv. Batch 273 time: 0:02:51 (avg: 0:02:37, remaining: 2:26:30)
# Exported lines 82200-82499 to steamspy_data.csv. Batch 274 time: 0:02:51 (avg: 0:02:37, remaining: 2:23:56)
# Exported lines 82500-82799 to steamspy_data.csv. Batch 275 time: 0:02:29 (avg: 0:02:37, remaining: 2:21:17)
# Exported lines 82800-83099 to steamspy_data.csv. Batch 276 time: 0:02:51 (avg: 0:02:37, remaining: 2:18:43)
# Exported lines 83100-83399 to steamspy_data.csv. Batch 277 time: 0:02:52 (avg: 0:02:37, remaining: 2:16:08)
# Exported lines 83400-83699 to steamspy_data.csv. Batch 278 time: 0:02:28 (avg: 0:02:37, remaining: 2:13:30)
# Exported lines 83700-83999 to steamspy_data.csv. Batch 279 time: 0:02:52 (avg: 0:02:37, remaining: 2:10:55)
# Exported lines 84000-84299 to steamspy_data.csv. Batch 280 time: 0:02:29 (avg: 0:02:37, remaining: 2:08:17)
# Exported lines 84300-84599 to steamspy_data.csv. Batch 281 time: 0:02:31 (avg: 0:02:37, remaining: 2:05:39)
# Exported lines 84600-84899 to steamspy_data.csv. Batch 282 time: 0:02:28 (avg: 0:02:37, remaining: 2:03:00)
# Exported lines 84900-85199 to steamspy_data.csv. Batch 283 time: 0:02:29 (avg: 0:02:37, remaining: 2:00:22)
# Exported lines 85200-85499 to steamspy_data.csv. Batch 284 time: 0:02:29 (avg: 0:02:37, remaining: 1:57:44)
# Exported lines 85500-85799 to steamspy_data.csv. Batch 285 time: 0:02:30 (avg: 0:02:37, remaining: 1:55:06)
# Exported lines 85800-86099 to steamspy_data.csv. Batch 286 time: 0:02:29 (avg: 0:02:37, remaining: 1:52:27)
# Exported lines 86100-86399 to steamspy_data.csv. Batch 287 time: 0:02:29 (avg: 0:02:37, remaining: 1:49:49)
# Exported lines 86400-86699 to steamspy_data.csv. Batch 288 time: 0:02:29 (avg: 0:02:37, remaining: 1:47:11)
# Exported lines 86700-86999 to steamspy_data.csv. Batch 289 time: 0:02:29 (avg: 0:02:37, remaining: 1:44:33)
# Exported lines 87000-87299 to steamspy_data.csv. Batch 290 time: 0:02:50 (avg: 0:02:37, remaining: 1:41:58)
# Exported lines 87300-87599 to steamspy_data.csv. Batch 291 time: 0:02:50 (avg: 0:02:37, remaining: 1:39:23)
# Exported lines 87600-87899 to steamspy_data.csv. Batch 292 time: 0:02:28 (avg: 0:02:37, remaining: 1:36:45)
# Exported lines 87900-88199 to steamspy_data.csv. Batch 293 time: 0:02:51 (avg: 0:02:37, remaining: 1:34:10)
# Exported lines 88200-88499 to steamspy_data.csv. Batch 294 time: 0:02:30 (avg: 0:02:37, remaining: 1:31:32)
# Exported lines 88500-88799 to steamspy_data.csv. Batch 295 time: 0:02:51 (avg: 0:02:37, remaining: 1:28:57)
# Exported lines 88800-89099 to steamspy_data.csv. Batch 296 time: 0:02:31 (avg: 0:02:37, remaining: 1:26:19)
# Exported lines 89100-89399 to steamspy_data.csv. Batch 297 time: 0:02:29 (avg: 0:02:37, remaining: 1:23:41)
# Exported lines 89400-89699 to steamspy_data.csv. Batch 298 time: 0:02:29 (avg: 0:02:37, remaining: 1:21:04)
# Exported lines 89700-89999 to steamspy_data.csv. Batch 299 time: 0:02:30 (avg: 0:02:37, remaining: 1:18:26)
# Exported lines 90000-90299 to steamspy_data.csv. Batch 300 time: 0:02:29 (avg: 0:02:37, remaining: 1:15:49)
# Exported lines 90300-90599 to steamspy_data.csv. Batch 301 time: 0:02:30 (avg: 0:02:37, remaining: 1:13:11)
# Exported lines 90600-90899 to steamspy_data.csv. Batch 302 time: 0:02:32 (avg: 0:02:37, remaining: 1:10:34)
# Exported lines 90900-91199 to steamspy_data.csv. Batch 303 time: 0:02:33 (avg: 0:02:37, remaining: 1:07:57)
# Exported lines 91200-91499 to steamspy_data.csv. Batch 304 time: 0:02:28 (avg: 0:02:37, remaining: 1:05:19)
# Exported lines 91500-91799 to steamspy_data.csv. Batch 305 time: 0:02:49 (avg: 0:02:37, remaining: 1:02:43)
# Exported lines 91800-92099 to steamspy_data.csv. Batch 306 time: 0:02:48 (avg: 0:02:37, remaining: 1:00:07)
# Exported lines 92100-92399 to steamspy_data.csv. Batch 307 time: 0:02:29 (avg: 0:02:37, remaining: 0:57:30)
# Exported lines 92400-92699 to steamspy_data.csv. Batch 308 time: 0:02:50 (avg: 0:02:37, remaining: 0:54:54)
# Exported lines 92700-92999 to steamspy_data.csv. Batch 309 time: 0:02:29 (avg: 0:02:37, remaining: 0:52:17)
# Exported lines 93000-93299 to steamspy_data.csv. Batch 310 time: 0:02:28 (avg: 0:02:37, remaining: 0:49:39)
# Exported lines 93300-93599 to steamspy_data.csv. Batch 311 time: 0:02:27 (avg: 0:02:37, remaining: 0:47:02)
# Exported lines 93600-93899 to steamspy_data.csv. Batch 312 time: 0:02:47 (avg: 0:02:37, remaining: 0:44:26)
# Exported lines 93900-94199 to steamspy_data.csv. Batch 313 time: 0:02:27 (avg: 0:02:37, remaining: 0:41:48)
# Exported lines 94200-94499 to steamspy_data.csv. Batch 314 time: 0:02:27 (avg: 0:02:37, remaining: 0:39:11)
# Exported lines 94500-94799 to steamspy_data.csv. Batch 315 time: 0:02:48 (avg: 0:02:37, remaining: 0:36:35)
# Exported lines 94800-95099 to steamspy_data.csv. Batch 316 time: 0:02:27 (avg: 0:02:37, remaining: 0:33:58)
# Exported lines 95100-95399 to steamspy_data.csv. Batch 317 time: 0:02:27 (avg: 0:02:37, remaining: 0:31:21)
# Exported lines 95400-95699 to steamspy_data.csv. Batch 318 time: 0:03:37 (avg: 0:02:37, remaining: 0:28:46)
# Exported lines 95700-95999 to steamspy_data.csv. Batch 319 time: 0:02:28 (avg: 0:02:37, remaining: 0:26:09)
# Exported lines 96000-96299 to steamspy_data.csv. Batch 320 time: 0:02:27 (avg: 0:02:37, remaining: 0:23:32)
# Exported lines 96300-96599 to steamspy_data.csv. Batch 321 time: 0:02:25 (avg: 0:02:37, remaining: 0:20:54)
# Exported lines 96600-96899 to steamspy_data.csv. Batch 322 time: 0:02:26 (avg: 0:02:37, remaining: 0:18:17)
# Exported lines 96900-97199 to steamspy_data.csv. Batch 323 time: 0:03:08 (avg: 0:02:37, remaining: 0:15:41)
# Exported lines 97200-97499 to steamspy_data.csv. Batch 324 time: 0:02:26 (avg: 0:02:37, remaining: 0:13:04)
# Exported lines 97500-97799 to steamspy_data.csv. Batch 325 time: 0:02:28 (avg: 0:02:37, remaining: 0:10:27)
# Exported lines 97800-98099 to steamspy_data.csv. Batch 326 time: 0:02:28 (avg: 0:02:37, remaining: 0:07:50)
# Exported lines 98100-98399 to steamspy_data.csv. Batch 327 time: 0:02:47 (avg: 0:02:37, remaining: 0:05:14)
# Exported lines 98400-98699 to steamspy_data.csv. Batch 328 time: 0:02:27 (avg: 0:02:37, remaining: 0:02:37)
# Exported lines 98700-98770 to steamspy_data.csv. Batch 329 time: 0:00:36 (avg: 0:02:36, remaining: 0:00:00)
#
# Processing batches complete. 98771 apps written

# %%
steam_spy_data = pd.read_csv('../data/download/steamspy_data.csv')

# %%
steam_spy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98771 entries, 0 to 98770
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            98771 non-null  int64
#  1   name             98533 non-null  object
#  2   developer        75948 non-null  object
#  3   publisher        75905 non-null  object
#  4   score_rank       45 non-null     float64
#  5   positive         98771 non-null  int64
#  6   negative         98771 non-null  int64
#  7   userscore        98771 non-null  int64
#  8   owners           98771 non-null  object
#  9   average_forever  98771 non-null  int64
#  10  average_2weeks   98771 non-null  int64
#  11  median_forever   98771 non-null  int64
#  12  median_2weeks    98771 non-null  int64
#  13  price            76142 non-null  float64
#  14  initialprice     76144 non-null  float64
#  15  discount         76144 non-null  float64
#  16  languages        76099 non-null  object
#  17  genre            75933 non-null  object
#  18  ccu              98771 non-null  int64
#  19  tags             98771 non-null  object
# dtypes: float64(4), int64(9), object(7)
# memory usage: 15.1+ MB

# %%
steam_spy_data.duplicated(subset="appid").sum()
# Out:
# 0
