# %%
#standard imports
import numpy as np
import pandas as pd
import json

# customisations - ensure tables show all columns
pd.set_option("display.max_columns", 100)

#imports for graphing
import seaborn as sns
import matplotlib.pyplot as plt

# %%
steamspy_data = pd.read_csv('../../data/download/steamspy_data.csv')

# %%
steamspy_data.head(5)
# Out:
#    appid                       name         developer publisher  score_rank  \
# 0     10             Counter-Strike             Valve     Valve         NaN
# 1     20      Team Fortress Classic             Valve     Valve         NaN
# 2     30              Day of Defeat             Valve     Valve         NaN
# 3     40         Deathmatch Classic             Valve     Valve         NaN
# 4     50  Half-Life: Opposing Force  Gearbox Software     Valve         NaN
#
#    positive  negative  userscore                    owners  average_forever  \
# 0    227880      5943          0  10,000,000 .. 20,000,000            10183
# 1      6923      1054          0   5,000,000 .. 10,000,000               38
# 2      5983       664          0    1,000,000 .. 2,000,000              212
# 3      2381       509          0   5,000,000 .. 10,000,000               25
# 4     20154      1024          0    2,000,000 .. 5,000,000              336
#
#    average_2weeks  median_forever  median_2weeks  price  initialprice  \
# 0             783             247            264  999.0         999.0
# 1               0              17              0  499.0         499.0
# 2               0              16              0  499.0         499.0
# 3               0              10              0  499.0         499.0
# 4              85             180             85  499.0         499.0
#
#    discount                                          languages   genre    ccu  \
# 0       0.0  English, French, German, Italian, Spanish - Sp...  Action  10110
# 1       0.0  English, French, German, Italian, Spanish - Sp...  Action     82
# 2       0.0  English, French, German, Italian, Spanish - Spain  Action    122
# 3       0.0  English, French, German, Italian, Spanish - Sp...  Action      7
# 4       0.0                    English, French, German, Korean  Action    131
#
#                                                 tags
# 0  {'Action': 5462, 'FPS': 4888, 'Multiplayer': 3...
# 1  {'Action': 761, 'FPS': 324, 'Multiplayer': 274...
# 2  {'FPS': 795, 'World War II': 266, 'Multiplayer...
# 3  {'Action': 633, 'FPS': 148, 'Classic': 113, 'M...
# 4  {'FPS': 913, 'Action': 347, 'Classic': 278, 'S...

# %%
steamspy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99449 entries, 0 to 99448
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            99449 non-null  int64
#  1   name             99157 non-null  object
#  2   developer        76375 non-null  object
#  3   publisher        76355 non-null  object
#  4   score_rank       45 non-null     float64
#  5   positive         99449 non-null  int64
#  6   negative         99449 non-null  int64
#  7   userscore        99449 non-null  int64
#  8   owners           99449 non-null  object
#  9   average_forever  99449 non-null  int64
#  10  average_2weeks   99449 non-null  int64
#  11  median_forever   99449 non-null  int64
#  12  median_2weeks    99449 non-null  int64
#  13  price            76568 non-null  float64
#  14  initialprice     76570 non-null  float64
#  15  discount         76570 non-null  float64
#  16  languages        76528 non-null  object
#  17  genre            76353 non-null  object
#  18  ccu              99449 non-null  int64
#  19  tags             99449 non-null  object
# dtypes: float64(4), int64(9), object(7)
# memory usage: 15.2+ MB
